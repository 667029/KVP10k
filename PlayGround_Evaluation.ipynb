# %% [markdown]
# <a href="https://colab.research.google.com/github/667029/KVP10k/blob/main/PlayGround_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Oppsett av modeller**

# %%
from transformers import AutoModel, pipeline, AutoProcessor, AutoModelForTokenClassification

# %%
# Setup base
base_pipe = pipeline("token-classification", model="microsoft/layoutlmv3-base")
base_processor = AutoProcessor.from_pretrained("microsoft/layoutlmv3-base")
base_model = AutoModel.from_pretrained("microsoft/layoutlmv3-base")
# Out:
# Some weights of LayoutLMv3ForTokenClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cpu
# preprocessor_config.json:   0%|          | 0.00/275 [00:00<?, ?B/s]

# %%
# Setup fusnd
funsd_pipe = pipeline("token-classification", model="nielsr/layoutlmv3-finetuned-funsd")
funsd_processor = AutoProcessor.from_pretrained("nielsr/layoutlmv3-finetuned-funsd")
funsd_model = AutoModelForTokenClassification.from_pretrained("nielsr/layoutlmv3-finetuned-funsd")
# Out:
# Device set to use cpu
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RobertaTokenizer'.
# The class this function is called from is 'LayoutLMv3TokenizerFast'.

# %%
# Setup cord
cord_pipe = pipeline("token-classification", model="nielsr/layoutlmv3-finetuned-cord")
cord_processor = AutoProcessor.from_pretrained("nielsr/layoutlmv3-finetuned-cord")
cord_model = AutoModelForTokenClassification.from_pretrained("nielsr/layoutlmv3-finetuned-cord")
# Out:
# Device set to use cpu
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RobertaTokenizer'.
# The class this function is called from is 'LayoutLMv3TokenizerFast'.

# %% [markdown]
# **Kjøring av modeller**
